# %% [markdown]
# <a href="https://colab.research.google.com/github/AnuLoveCoding/Anu.lovescoding/blob/main/tesla_stock_price.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn import metrics

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("TSLA.csv")

# %%
df.head()
# Out:
#         Date       Open   High        Low      Close  Adj Close    Volume
# 0  6/29/2010  19.000000  25.00  17.540001  23.889999  23.889999  18766300
# 1  6/30/2010  25.790001  30.42  23.299999  23.830000  23.830000  17187100
# 2   7/1/2010  25.000000  25.92  20.270000  21.959999  21.959999   8218800
# 3   7/2/2010  23.000000  23.10  18.709999  19.200001  19.200001   5139800
# 4   7/6/2010  20.000000  20.00  15.830000  16.110001  16.110001   6866900

# %%
df.shape
# Out:
# (2416, 7)

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2416.000000  2416.000000  2416.000000  2416.000000  2416.000000
# mean    186.271147   189.578224   182.916639   186.403651   186.403651
# std     118.740163   120.892329   116.857591   119.136020   119.136020
# min      16.139999    16.629999    14.980000    15.800000    15.800000
# 25%      34.342498    34.897501    33.587501    34.400002    34.400002
# 50%     213.035004   216.745002   208.870002   212.960007   212.960007
# 75%     266.450012   270.927513   262.102501   266.774994   266.774994
# max     673.690002   786.140015   673.520020   780.000000   780.000000
#
#              Volume
# count  2.416000e+03
# mean   5.572722e+06
# std    4.987809e+06
# min    1.185000e+05
# 25%    1.899275e+06
# 50%    4.578400e+06
# 75%    7.361150e+06
# max    4.706500e+07

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2416 entries, 0 to 2415
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2416 non-null   object
#  1   Open       2416 non-null   float64
#  2   High       2416 non-null   float64
#  3   Low        2416 non-null   float64
#  4   Close      2416 non-null   float64
#  5   Adj Close  2416 non-null   float64
#  6   Volume     2416 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 132.2+ KB

# %% [markdown]
# # **Exploratory Data Analysis**
#
# ---
#
#
#
# ---

# %%
plt.figure(figsize=(15,5))
plt.plot(df['Close'])
plt.title('Tesla Close price.', fontsize=15)
plt.ylabel('Price in dollars.')
plt.show()

# %%
df.head()
# Out:
#         Date       Open   High        Low      Close  Adj Close    Volume
# 0  6/29/2010  19.000000  25.00  17.540001  23.889999  23.889999  18766300
# 1  6/30/2010  25.790001  30.42  23.299999  23.830000  23.830000  17187100
# 2   7/1/2010  25.000000  25.92  20.270000  21.959999  21.959999   8218800
# 3   7/2/2010  23.000000  23.10  18.709999  19.200001  19.200001   5139800
# 4   7/6/2010  20.000000  20.00  15.830000  16.110001  16.110001   6866900

# %%
df[df['Close'] == df['Adj Close']].shape
# Out:
# (2416, 7)

# %%
df = df.drop(['Adj Close'], axis=1)

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
len(df.index)
# Out:
# 2416

# %%
df.isnull().sum()
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
features = ['Open', 'High', 'Low', 'Close', 'Volume']

plt.subplots(figsize=(20,10))

for i, col in enumerate(features):
  plt.subplot(2,3,i+1)
  plt.title(col)
  sb.distplot(df[col])
plt.show()

# %%
plt.subplots(figsize=(20,10))
for i, col in enumerate(features):
  plt.subplot(2,3,i+1)
  sb.boxplot(df[col])
plt.show()

# %% [markdown]
# # **Feature Engineering**

# %%
splitted = df['Date'].str.split('/', expand=True)

df['day'] = splitted[1].astype('int')
df['month'] = splitted[0].astype('int')
df['year'] = splitted[2].astype('int')

df.head()
# Out:
#         Date       Open   High        Low      Close    Volume  day  month  \
# 0  6/29/2010  19.000000  25.00  17.540001  23.889999  18766300   29      6
# 1  6/30/2010  25.790001  30.42  23.299999  23.830000  17187100   30      6
# 2   7/1/2010  25.000000  25.92  20.270000  21.959999   8218800    1      7
# 3   7/2/2010  23.000000  23.10  18.709999  19.200001   5139800    2      7
# 4   7/6/2010  20.000000  20.00  15.830000  16.110001   6866900    6      7
#
#    year
# 0  2010
# 1  2010
# 2  2010
# 3  2010
# 4  2010

# %%
df['is_quarter_end'] = np.where(df['month']%3==0,1,0)
df.head()
# Out:
#         Date       Open   High        Low      Close    Volume  day  month  \
# 0  6/29/2010  19.000000  25.00  17.540001  23.889999  18766300   29      6
# 1  6/30/2010  25.790001  30.42  23.299999  23.830000  17187100   30      6
# 2   7/1/2010  25.000000  25.92  20.270000  21.959999   8218800    1      7
# 3   7/2/2010  23.000000  23.10  18.709999  19.200001   5139800    2      7
# 4   7/6/2010  20.000000  20.00  15.830000  16.110001   6866900    6      7
#
#    year  is_quarter_end
# 0  2010               1
# 1  2010               1
# 2  2010               0
# 3  2010               0
# 4  2010               0

# %%
# Convert the Date column to a datetime format using pd.to_datetime().
df['Date'] = pd.to_datetime(df['Date'])

# %%
#  Recalculate the year column after converting the Date column to a datetime format
df['year'] = df['Date'].dt.year

# %%
# Run the groupby operation again.
data_grouped = df.groupby('year').mean()

# %%
# Plot the bar chart as before
plt.subplots(figsize=(20,10))

for i, col in enumerate(['Open', 'High', 'Low', 'Close']):
  plt.subplot(2,2,i+1)
  data_grouped[col].plot.bar()
plt.show()

# %%
df.groupby('is_quarter_end').mean()
# Out:
#                                         Date        Open        High  \
# is_quarter_end
# 0              2015-04-15 12:01:46.930693120  185.875081  189.254226
# 1              2015-04-15 09:25:12.000000000  187.071200  190.232700
#
#                        Low       Close        Volume        day     month  \
# is_quarter_end
# 0               182.449499  186.085081  5.767062e+06  15.710396  6.173886
# 1               183.860262  187.047163  5.180154e+06  15.825000  7.597500
#
#                        year
# is_quarter_end
# 0               2014.816213
# 1               2014.697500

# %%
df['open-close'] = df['Open'] - df['Close']
df['low-high'] = df['Low'] - df['High']
df['target'] = np.where(df['Close'].shift(-1) > df['Close'], 1, 0)

# %%
plt.pie(df['target'].value_counts().values,
		labels=[0, 1], autopct='%1.1f%%')
plt.show()

# %%
plt.figure(figsize=(10, 10))

# As our concern is with the highly
# correlated features only so, we will visualize
# our heatmap as per that criteria only.
sb.heatmap(df.corr() > 0.9, annot=True, cbar=False)
plt.show()

# %%
features = df[['open-close', 'low-high', 'is_quarter_end']]
target = df['target']

scaler = StandardScaler()
features = scaler.fit_transform(features)

X_train, X_valid, Y_train, Y_valid = train_test_split(
	features, target, test_size=0.1, random_state=2022)
print(X_train.shape, X_valid.shape)
# Out:
# (2174, 3) (242, 3)

# %%
# models = []
# # Add models to the list
# models.append(LogisticRegression())
# models.append(SVC())


# for i in range(3):
#     models[i].fit(X_train, Y_train)

#     print(f'{models[i]} : ')
#     print('Training Accuracy : ', metrics.roc_auc_score(
#         Y_train, models[i].predict_proba(X_train)[:,1]))
#     print('Validation Accuracy : ', metrics.roc_auc_score(
#         Y_valid, models[i].predict_proba(X_valid)[:,1]))
#     print()

# %%
# models = []
# # Add models to the list
# models.append(LogisticRegression())
# models.append(SVC(probability=True))


# for i in range(3):
#     models[i].fit(X_train, Y_train)

#     print(f'{models[i]} : ')
#     print('Training Accuracy : ', metrics.roc_auc_score(
#         Y_train, models[i].predict_proba(X_train)[:,1]))
#     print('Validation Accuracy : ', metrics.roc_auc_score(
#         Y_valid, models[i].predict_proba(X_valid)[:,1]))
#     print()

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
# Add a third model to the list
models.append(DecisionTreeClassifier())

# Change the index of the element being accessed
for i in range(2):
    models[i].fit(X_train, Y_train)

    print(f'{models[i]} : ')
    print('Training Accuracy : ', metrics.roc_auc_score(
        Y_train, models[i].predict_proba(X_train)[:,1]))
    print('Validation Accuracy : ', metrics.roc_auc_score(
        Y_valid, models[i].predict_proba(X_valid)[:,1]))
    print()
# Out:
# LogisticRegression() :
# Training Accuracy :  0.5228802330060918
# Validation Accuracy :  0.4923371647509579
#
# SVC(probability=True) :
# Training Accuracy :  0.45969680420968856
# Validation Accuracy :  0.4904898741105638
